# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.src.legacy.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import tensorflow as tf
# ----> 2 from keras.src.legacy.preprocessing.image import ImageDataGenerator
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\_tf_keras\__init__.py:1, in <module>
# ----> 1 from keras._tf_keras import keras
#
# ...

# %%
tf.__version__
# Out:
# '2.17.0'

# %%
# rescale = 1./255:

# Scales the pixel values from 0–255 to 0–1.

# Normalization helps the model converge faster.

# shear_range = 0.2:

# Applies shearing transformation (slanting the image), like skewing horizontally/vertically by 20%.

# zoom_range = 0.2:

# Randomly zooms in on images by up to 20%.

# horizontal_flip = True:

# Randomly flips the image horizontally (e.g., a cat facing left becomes a cat facing right)

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory(r'D:\Data Science All\Data Science AI ML 45 Days Training\DL_PPTS\dogs-vs-cats\train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 25000 images belonging to 1 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory(r'D:\Data Science All\Data Science AI ML 45 Days Training\DL_PPTS\dogs-vs-cats\test1',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 12500 images belonging to 1 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
#
# NameError: name 'cnn' is not defined

# %%
# filters=32: Creates 32 convolution filters (also called feature detectors).

# kernel_size=3: Each filter is 3x3 in size.

# activation='relu': Applies ReLU (Rectified Linear Unit) to introduce non-linearity.

# input_shape=[64, 64, 3]: Input image size — 64x64 pixels with 3 color channels (RGB).

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
# pool_size=2: Looks at 2x2 windows in the feature map.

# strides=2: Moves 2 steps at a time (no overlap).

# Effect: Reduces spatial size (downsampling), keeps only strongest features → improves efficiency and reduces overfitting.

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
# Another 32 filters (3x3) applied to previously pooled features.

# Learns more complex patterns like shapes, curves, eyes, etc.

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
# Converts the 2D feature maps into a 1D feature vector to feed into Dense layers.

# For example, a (16x16x32) output becomes a vector of 8192 values.

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
# 128 neurons.

# ReLU activation.

# Processes flattened features and learns complex decision boundaries.

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
# 1 neuron because it's a binary classification (cat vs dog).

# Sigmoid activation gives a probability between 0 and 1.

# Output close to 0 → class 0 (dog)

# Output close to 1 → class 1 (cat)

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# C:\Users\SPaRK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1430s 2s/step - accuracy: 0.9936 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 1.4114e-12
# Epoch 2/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 127ms/step - accuracy: 1.0000 - loss: 1.4160e-11 - val_accuracy: 1.0000 - val_loss: 1.4110e-12
# Epoch 3/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 1.0000 - loss: 2.8002e-12 - val_accuracy: 1.0000 - val_loss: 1.4108e-12
# Epoch 4/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 121s 154ms/step - accuracy: 1.0000 - loss: 9.3363e-13 - val_accuracy: 1.0000 - val_loss: 1.4108e-12
# Epoch 5/25
# ...

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('D:\Data Science All\Data Science AI ML 45 Days Training\DL_PPTS\dogs-vs-cats\single_prediction\cat_or_dog_1.jpg',
                            target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 0:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step

# %%
print(prediction)
# Out:
# cat
