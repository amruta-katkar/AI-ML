# %%
from numpy import *
import pandas as pd
import numpy as np

# %%
# dataframe
data = {
    "name":["Ajay","Vijay","Ram","Sham","Sita","Gita"],
    "id" : [1,2,3,4,5,6],
    "Salary" : [10000,2000000,230999,234885,2361,85346]
}
print(data)
# Out:
# {'name': ['Ajay', 'Vijay', 'Ram', 'Sham', 'Sita', 'Gita'], 'id': [1, 2, 3, 4, 5, 6], 'Salary': [10000, 2000000, 230999, 234885, 2361, 85346]}

# %%
dataset = DataFrame(data)

# %%
dataset
# Out:
#     name  id   Salary
# 0   Ajay   1    10000
# 1  Vijay   2  2000000
# 2    Ram   3   230999
# 3   Sham   4   234885
# 4   Sita   5     2361
# 5   Gita   6    85346

# %%
dataset["Salary"]
# Out:
# 0      10000
# 1    2000000
# 2     230999
# 3     234885
# 4       2361
# 5      85346
# Name: Salary, dtype: int64

# %%
dataset["Salary"].sum()
# Out:
# 2563591

# %%
dataset["Salary"].count()
# Out:
# 6

# %%
dataset["Salary"].std()
# Out:
# 777250.0086050605

# %%
dataset["Salary"].min()
# Out:
# 2361

# %%
dataset["Salary"].mode()
# Out:
# 0       2361
# 1      10000
# 2      85346
# 3     230999
# 4     234885
# 5    2000000
# Name: Salary, dtype: int64

# %%
dataset["Salary"].max()
# Out:
# 2000000

# %%
dataset.head()
# Out:
#     name  id   Salary
# 0   Ajay   1    10000
# 1  Vijay   2  2000000
# 2    Ram   3   230999
# 3   Sham   4   234885
# 4   Sita   5     2361

# %%
dataset.tail(2)
# Out:
#    name  id  Salary
# 4  Sita   5    2361
# 5  Gita   6   85346

# %%
dataset.describe()
# Out:
#              id        Salary
# count  6.000000  6.000000e+00
# mean   3.500000  4.272652e+05
# std    1.870829  7.772500e+05
# min    1.000000  2.361000e+03
# 25%    2.250000  2.883650e+04
# 50%    3.500000  1.581725e+05
# 75%    4.750000  2.339135e+05
# max    6.000000  2.000000e+06

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   id      6 non-null      int64
#  2   Salary  6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
dataset["Salary"].mean()
# Out:
# 427265.1666666667

# %% [raw]
# m=round(dataset["Salary"].mean())
# m

# %%
df = pd.read_csv("D:\AIML-internship\AllData\weather_data.csv")

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df1 = pd.read_excel("D:\AIML-internship\AllData\weather_data.xlsx","Sheet1")
df1
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
# tuple list
weather_data = [
    ("2017-01-01",32,6,"Rain"),
    ("2017-01-02",35,7,"Sunny"),
    ("2017-01-03",28,2,"Snow")
]

# %%
w = pd.DataFrame(data = weather_data,columns=["day","temp","windspeed","event"])

# %%
w
# Out:
#           day  temp  windspeed  event
# 0  2017-01-01    32          6   Rain
# 1  2017-01-02    35          7  Sunny
# 2  2017-01-03    28          2   Snow

# %%
# list of dictionaries
we = [
    {"day":'1/2/2022',"temparature":33,"windspeed":34},
    {"day":'2/2/2022',"temparature":33,"windspeed":34},
    {"day":'3/2/2022',"temparature":33,"windspeed":34},
    {"day":'4/2/2022',"temparature":33,"windspeed":34}

]

# %%
we
# Out:
# [{'day': '1/2/2022', 'temparature': 33, 'windspeed': 34},
#  {'day': '2/2/2022', 'temparature': 33, 'windspeed': 34},
#  {'day': '3/2/2022', 'temparature': 33, 'windspeed': 34},
#  {'day': '4/2/2022', 'temparature': 33, 'windspeed': 34}]

# %%
df1 = pd.DataFrame(data = we)

# %%
df1
# Out:
#         day  temparature  windspeed
# 0  1/2/2022           33         34
# 1  2/2/2022           33         34
# 2  3/2/2022           33         34
# 3  4/2/2022           33         34
