# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([100,234,123,452,456,125])

# %% [markdown]
# # linechart

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # grid

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# # various signs for points

# %%
plt.plot(x,y,'P')
plt.show()

# %%
plt.plot(x,y,'p')
plt.show()

# %%
plt.plot(x,y,'d')
plt.show()

# %%
plt.plot(x,y,'s')
plt.show()

# %% [markdown]
# # show line

# %%
plt.plot(x,y,'P--r')
plt.show()

# %% [markdown]
# # line with various colors

# %%
plt.plot(x,y,'p-.g')
plt.show()

# %%
plt.plot(x,y,'s:b',ms=10)
plt.show()

# %%
plt.plot(x,y,'s:y',ms=10,mec='r')
plt.show()

# %%
plt.plot(x,y,'s:y',ms=10,mec = 'r',color="b")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13616\3139948791.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "s:y" (-> color='y'). The keyword argument will take precedence.
#   plt.plot(x,y,'s:y',ms=10,mec = 'r',color="b")

# %%
plt.plot(x,y,'*',ms=10,mec='y',mfc='r',ls='-.',color='b')
plt.grid()
plt.show()

# %%
plt.plot(x,y,'P',ms=15,mec='y',mfc='r',ls='-.',color='b',linewidth=2)
plt.grid()
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([40,50,60,70,200,400])
plt.grid(color='y')
plt.plot(x,y,'d',mec='b',mfc='#27f5f5',color='#f52727',ls='--',ms=10)
plt.show()

# %%
x = np.array([10,30,50,70,90,120])
y = np.array([100,340,209,450,454,600])
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([10,30,50,70,90,120])
y = np.array([100,340,209,450,454,600])
plt.plot(x,y,'o')
plt.xlabel('c label')
plt.ylabel('y label')
plt.show()

# %%
x = np.array([10,30,50,70,90,120])
y = np.array([100,340,209,450,454,600])
plt.plot(x,y,'o')
plt.xlabel('c label')
plt.ylabel('y label')
plt.title('simple chart')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([30,45,56,70,80,100])
plt.plot(x,y,'o')
plt.xlabel('year of experience')
plt.ylabel('salary')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([30,45,56,70,80,100])

a = np.array([1,2,3,4,5,6])
b = np.array([40,45,56,65,85,150])

f1 = {'family' : 'serif', 'color':'r','size':15}
f2 = {'family' : 'times new roman', 'color':'hotpink','size':12}
f3 = {'family' : 'monospace', 'color':'black','size':12}


plt.plot(x,y,a,b,'o')
plt.xlabel('year of experience',fontdict=f3)
plt.ylabel('salary',fontdict=f3)
plt.title('salary prediction',fontdict=f1)
plt.show()

# %%
# plot1
x = np.array([1,2,3,4,5,6])
y = np.array([30,45,56,70,80,100])

f1 = {'family' : 'serif', 'color':'r','size':15}
f2 = {'family' : 'times new roman', 'color':'hotpink','size':12}
f3 = {'family' : 'monospace', 'color':'black','size':12}



plt.title('IIT salary prediction',fontdict=f1)
plt.xlabel('year of experience',fontdict=f2)
plt.ylabel('salary in k',fontdict=f2)

# plot 2
a = np.array([1,2,3,4,5,6])
b = np.array([40,45,56,65,85,150])

plt.title('IIM salary prediction',fontdict=f1)
plt.xlabel('year of experience',fontdict=f3)
plt.ylabel('salary in k',fontdict=f3)

# plot3
m = np.array([1,2,3,4,5,6])
n = np.array([35,56,78,89,90,120])

plt.title('VIT salary prediction',fontdict=f1)
plt.xlabel('year of experience',fontdict=f3)
plt.ylabel('salary in k',fontdict=f3)
# Out:
# Text(0, 0.5, 'salary in k')

# %%
plt.rcParams['figure.figsize']=(10,3)

# plot1
x = np.array([1,2,3,4,5,6])
y = np.array([30,45,56,70,80,100])

plt.subplot(1,3,1)
plt.plot(x,y,marker="+",mec="green",mfc='y',ms=20)

# plot 2
plt.title('IIT salary prediction',fontdict=f1)
# plot 2
a = np.array([1,2,3,4,5,6])
b = np.array([40,45,56,65,85,150])

plt.subplot(1,3,2)
plt.plot(a,b,marker='H',mec='y',mfc='r',ms=12)

# plot 1 label
plt.title("IIm salary preddiction")


# plot
m = np.array([1,2,3,4,5,6])
n = np.array([35,56,78,89,90,120])

plt.subplot(1,3,3)
plt.plot(a,b,marker='P',mec='b',mfc='y',ms=16)

# plot 3 label
plt.title("VIT salary prediction")

plt.show()

# %%
days = [1,2,3,4,5,6,7]
min_temp = [20,23,22,25,30,28,36]
max_temp = [35,34,37,40,40,38,46]
avg_temp = [27,29,31,35,35,33,40]

plt.plot(days,max_temp,label='max')
plt.plot(days,min_temp,label='min')
plt.plot(days,avg_temp,label='avg')

# %%
days = [1,2,3,4,5,6,7]
min_temp = [20,23,22,25,30,28,36]
max_temp = [35,34,37,40,40,38,46]
avg_temp = [27,29,31,35,35,33,40]

plt.plot(days,max_temp,label='max')
plt.plot(days,min_temp,label='min')
plt.plot(days,avg_temp,label='avg')

plt.legend(loc='best')

# %%
days = [1,2,3,4,5,6,7]
min_temp = [20,23,22,25,30,28,36]
max_temp = [35,34,37,40,40,38,46]
avg_temp = [27,29,31,35,35,33,40]

plt.plot(days,max_temp,'s--',label='max')
plt.plot(days,min_temp,'s--',label='min')
plt.plot(days,avg_temp,'s--',label='avg')

plt.xlabel('days',fontdict=f3)
plt.ylabel('Temperature',fontdict=f3)
plt.title('Weather',fontdict=f1)


plt.legend(loc='upper left',shadow = True,fontsize='large')

# %%
company = ["Amazon","Flipkart","Myntra","limeshop","shopify"]
revenue = [200,250,230,150,180]
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3, 4])

# %%
company = ["Amazon","Flipkart","Myntra","limeshop","shopify"]
revenue = [200,250,230,150,180]
xpos = np.arange(len(company))

plt.bar(company,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
ompany = ["Amazon","Flipkart","Myntra","limeshop","shopify"]
revenue = [200,250,230,150,180]
xpos = np.arange(len(company))

plt.bar(company,revenue)
plt.xticks(xpos,company)
# Out:
# ([<matplotlib.axis.XTick at 0x214a82c7010>,
# ...
#  [Text(0, 0, 'Amazon'),
#   Text(1, 0, 'Flipkart'),
#   Text(2, 0, 'Myntra'),
#   Text(3, 0, 'limeshop'),
#   Text(4, 0, 'shopify')])

# %%
ompany = ["Amazon","Flipkart","Myntra","limeshop","shopify"]
revenue = [200,250,230,150,180]
profit = [40,30,43,45,12]
xpos = np.arange(len(company))

plt.bar(company,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='Profit')

plt.xticks(xpos,company)

plt.ylabel('Revenue in billion')
plt.xlabel('ecommaerce stocks of market')


plt.legend(loc='upper left',shadow = True,fontsize='large')
